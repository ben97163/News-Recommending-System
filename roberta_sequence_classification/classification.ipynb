# %%
# !gdown https://drive.google.com/u/0/uc?id=1k_A-G8WYVb2-JvRb5pAYDUKxDHjA4g-u&export=download
# !unzip data.zip
# !rm data.zip

# %%
# !pip install -r drive/MyDrive/ADL-final/requirements.txt
# !pip install transformers

# %%
# train
# !python drive/MyDrive/ADL-final/run_classification.py \
  --model_name_or_path hfl/chinese-roberta-wwm-ext \
  --train_file data/train.json \
  --validation_file data/val.json \
  --metric_name accuracy \
  --text_column_names title,content \
  --label_column_name label \
  --text_column_delimiter \n \
  --do_train \
  --do_eval \
  --max_seq_length 512 \
  --per_device_train_batch_size 8 \
  --gradient_accumulation_steps 4 \
  --per_device_eval_batch_size 8 \
  --learning_rate 2e-5 \
  --num_train_epochs 20 \
  --output_dir drive/MyDrive/ADL-final/result_with_content/ \
  # --overwrite_output_dir
# Out:
# 2023-12-25 11:34:32.790695: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-25 11:34:32.790762: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-25 11:34:32.792085: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-25 11:34:33.853429: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 12/25/2023 11:34:37 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# 12/25/2023 11:34:37 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# ...

# %%
# eval
# !python drive/MyDrive/ADL-final/run_classification.py \
  --model_name_or_path drive/MyDrive/ADL-final/result/ \
  --train_file data/train.json \
  --validation_file data/train.json \
  --metric_name accuracy \
  --text_column_names title,content \
  --label_column_name label \
  --do_eval \
  --max_seq_length 512 \
  --per_device_train_batch_size 8 \
  --gradient_accumulation_steps 4 \
  --per_device_eval_batch_size 8 \
  --learning_rate 2e-5 \
  --num_train_epochs 15 \
  --output_dir drive/MyDrive/ADL-final/eval_result/ \
  --overwrite_output_dir
# Out:
# 2023-12-25 07:21:16.446664: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-25 07:21:16.446726: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-25 07:21:16.448244: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-25 07:21:17.686955: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 12/25/2023 07:21:20 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# 12/25/2023 07:21:20 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# ...

# %%
import pandas as pd
import json

# Specify the path to your JSON file
json_file_path = 'data/val.json'

# Open and read the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
print(len(data))
# Out:
# 1068
